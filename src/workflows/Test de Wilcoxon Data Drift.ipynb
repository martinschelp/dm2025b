# %% [markdown]
# # Test de Wilcoxon Data Drift

# %%
# Define all method vectors
vBlue <- c(6.435, 6.505, 6.575, 7.506, 7.586, 5.974, 7.336, 6.055, 6.875, 6.845)
vIPC <- c(7.506, 7.316, 6.735, 6.715, 7.055, 6.645, 8.136, 7.836, 6.695, 6.195)
vNinguno <- c(6.885, 7.446, 6.645, 6.365, 6.985, 7.406, 7.356, 6.995, 7.486, 6.605)
vSTD <- c()  # Empty vector - will be skipped
vRankSimple <- c(3.873, 6.225, 6.625, 5.284, 7.045)
vRankCero <- c(7.045, 7.266, 7.125, 7.005, 7.636, 7.255)
vNucleo <- c(6.225, 6.425, 7.065, 7.115, 7.135)

# %% [markdown]
# ---

# %%
# Comprehensive Wilcoxon Test Comparison for All Methods
# Data Mining 2025 - Model Comparison Analysis

# USO TODOS LOS VALORES, SI n!=m bajo la dimension de n para matchear

# Create list of all methods (excluding empty STD)
methods <- list(
  "Blue" = vBlue,
  "IPC" = vIPC,
  "Ninguno" = vNinguno,
  "RankSimple" = vRankSimple,
  "RankCero" = vRankCero,
  "Nucleo" = vNucleo
)

# Function to perform Wilcoxon test between two vectors
perform_wilcoxon_test <- function(vec1, vec2, name1, name2) {
  # Always use paired test by truncating to minimum length
  min_length <- min(length(vec1), length(vec2))
  
  # Truncate both vectors to the same length (first n values with matching seeds)
  vec1_truncated <- vec1[1:min_length]
  vec2_truncated <- vec2[1:min_length]
  
  # Use paired test with truncated vectors
  wt <- wilcox.test(vec1_truncated, vec2_truncated, paired = TRUE)
  test_type <- "paired"
  
  pvalue <- wt$p.value
  mean1 <- mean(vec1_truncated)
  mean2 <- mean(vec2_truncated)
  
  # Determine result
  result <- 0
  interpretation <- "No significant difference"
  
  if (pvalue < 0.05) {
    if (mean1 > mean2) {
      result <- 1
      interpretation <- paste(name1, "significantly better than", name2)
    } else {
      result <- 2
      interpretation <- paste(name2, "significantly better than", name1)
    }
  }
  
  return(list(
    comparison = paste(name1, "vs", name2),
    test_type = test_type,
    n1 = length(vec1_truncated),
    n2 = length(vec2_truncated),
    original_n1 = length(vec1),
    original_n2 = length(vec2),
    mean1 = round(mean1, 3),
    mean2 = round(mean2, 3),
    pvalue = round(pvalue, 4),
    result = result,
    interpretation = interpretation
  ))
}

# Perform all pairwise comparisons
results <- list()
method_names <- names(methods)
comparison_count <- 0

cat("=== WILCOXON TEST RESULTS FOR ALL METHOD PAIRS ===\n\n")

for (i in 1:(length(methods) - 1)) {
  for (j in (i + 1):length(methods)) {
    comparison_count <- comparison_count + 1
    
    name1 <- method_names[i]
    name2 <- method_names[j]
    vec1 <- methods[[i]]
    vec2 <- methods[[j]]
    
    # Perform test
    test_result <- perform_wilcoxon_test(vec1, vec2, name1, name2)
    results[[comparison_count]] <- test_result
    
    # Print individual result
    cat("Comparison", comparison_count, ":", test_result$comparison, "\n")
    cat("  Test type:", test_result$test_type, "\n")
    cat("  Sample sizes used: n =", test_result$n1, "(truncated from", test_result$original_n1, "vs", test_result$original_n2, ")\n")
    cat("  Means:", name1, "=", test_result$mean1, ",", name2, "=", test_result$mean2, "\n")
    cat("  P-value:", test_result$pvalue, "\n")
    cat("  Result:", test_result$interpretation, "\n")
    cat("  ---\n")
  }
}

# Create summary table
cat("\n=== SUMMARY TABLE ===\n")
cat(sprintf("%-20s %-10s %-8s %-12s %-8s %-8s %-10s %s\n", 
            "Comparison", "Test", "n_used", "Original_n", "Mean1", "Mean2", "P-value", "Result"))
cat(paste(rep("-", 95), collapse=""), "\n")

for (result in results) {
  original_sizes <- paste0(result$original_n1, "vs", result$original_n2)
  cat(sprintf("%-20s %-10s %-8d %-12s %-8.3f %-8.3f %-10.4f %d\n",
              result$comparison,
              result$test_type,
              result$n1,
              original_sizes,
              result$mean1,
              result$mean2,
              result$pvalue,
              result$result))
}

# Summary statistics
cat("\n=== OVERALL SUMMARY ===\n")
cat("Total comparisons performed:", comparison_count, "\n")

significant_results <- sum(sapply(results, function(x) x$result != 0))
cat("Significant differences found:", significant_results, "\n")

cat("All tests performed as paired tests using truncated vectors\n")

# Method performance ranking by mean
method_means <- sapply(methods, mean)
method_ranking <- sort(method_means, decreasing = TRUE)

cat("\n=== METHOD RANKING BY MEAN PERFORMANCE ===\n")
for (i in 1:length(method_ranking)) {
  cat(i, ".", names(method_ranking)[i], ":", round(method_ranking[i], 3), "\n")
}

cat("\nNote: Results with code 0 = no significant difference")
cat("\n      Results with code 1 = first method significantly better")
cat("\n      Results with code 2 = second method significantly better\n")
# Out:
# === WILCOXON TEST RESULTS FOR ALL METHOD PAIRS ===
#
# Comparison 1 : Blue vs IPC
#   Test type: paired
#   Sample sizes used: n = 10 (truncated from 10 vs 10 )
#   Means: Blue = 6.769 , IPC = 7.083
#   P-value: 0.2324
#   Result: No significant difference
#   ---
# Comparison 2 : Blue vs Ninguno
#   Test type: paired
#   Sample sizes used: n = 10 (truncated from 10 vs 10 )
#   Means: Blue = 6.769 , Ninguno = 7.017
#   P-value: 0.3223
#   Result: No significant difference
#   ---
# Comparison 3 : Blue vs RankSimple
#   Test type: paired
#   Sample sizes used: n = 5 (truncated from 10 vs 5 )
#   Means: Blue = 6.921 , RankSimple = 5.81
#   P-value: 0.125
#   Result: No significant difference
#   ---
# Comparison 4 : Blue vs RankCero
#   Test type: paired
#   Sample sizes used: n = 5 (truncated from 10 vs 5 )
#   Means: Blue = 6.921 , RankCero = 7.215
#   P-value: 0.1875
#   Result: No significant difference
#   ---
# Comparison 5 : Blue vs Nucleo
#   Test type: paired
#   Sample sizes used: n = 5 (truncated from 10 vs 5 )
#   Means: Blue = 6.921 , Nucleo = 6.793
#   P-value: 0.625
#   Result: No significant difference
#   ---
# Comparison 6 : IPC vs Ninguno
#   Test type: paired
#   Sample sizes used: n = 10 (truncated from 10 vs 10 )
#   Means: IPC = 7.083 , Ninguno = 7.017
#   P-value: 0.7695
#   Result: No significant difference
#   ---
# Comparison 7 : IPC vs RankSimple
#   Test type: paired
#   Sample sizes used: n = 5 (truncated from 10 vs 5 )
#   Means: IPC = 7.065 , RankSimple = 5.81
#   P-value: 0.0625
#   Result: No significant difference
#   ---
# Comparison 8 : IPC vs RankCero
#   Test type: paired
#   Sample sizes used: n = 5 (truncated from 10 vs 5 )
#   Means: IPC = 7.065 , RankCero = 7.215
#   P-value: 0.625
#   Result: No significant difference
#   ---
# Comparison 9 : IPC vs Nucleo
#   Test type: paired
#   Sample sizes used: n = 5 (truncated from 10 vs 5 )
#   Means: IPC = 7.065 , Nucleo = 6.793
#   P-value: 0.8125
#   Result: No significant difference
#   ---
# Comparison 10 : Ninguno vs RankSimple
#   Test type: paired
#   Sample sizes used: n = 5 (truncated from 10 vs 5 )
#   Means: Ninguno = 6.865 , RankSimple = 5.81
#   P-value: 0.1875
#   Result: No significant difference
#   ---
# Comparison 11 : Ninguno vs RankCero
#   Test type: paired
#   Sample sizes used: n = 5 (truncated from 10 vs 5 )
#   Means: Ninguno = 6.865 , RankCero = 7.215
#   P-value: 0.1875
#   Result: No significant difference
#   ---
# Comparison 12 : Ninguno vs Nucleo
#   Test type: paired
#   Sample sizes used: n = 5 (truncated from 10 vs 5 )
#   Means: Ninguno = 6.865 , Nucleo = 6.793
#   P-value: 1
#   Result: No significant difference
#   ---
# Comparison 13 : RankSimple vs RankCero
#   Test type: paired
#   Sample sizes used: n = 5 (truncated from 5 vs 5 )
#   Means: RankSimple = 5.81 , RankCero = 7.215
#   P-value: 0.0625
#   Result: No significant difference
#   ---
# Comparison 14 : RankSimple vs Nucleo
#   Test type: paired
#   Sample sizes used: n = 5 (truncated from 5 vs 5 )
#   Means: RankSimple = 5.81 , Nucleo = 6.793
#   P-value: 0.0625
#   Result: No significant difference
#   ---
# Comparison 15 : RankCero vs Nucleo
#   Test type: paired
#   Sample sizes used: n = 5 (truncated from 5 vs 5 )
#   Means: RankCero = 7.215 , Nucleo = 6.793
#   P-value: 0.1875
#   Result: No significant difference
#   ---
#
# === SUMMARY TABLE ===
# Comparison           Test       n_used   Original_n   Mean1    Mean2    P-value    Result
# -----------------------------------------------------------------------------------------------
# Blue vs IPC          paired     10       10vs10       6.769    7.083    0.2324     0
# Blue vs Ninguno      paired     10       10vs10       6.769    7.017    0.3223     0
# Blue vs RankSimple   paired     5        10vs5        6.921    5.810    0.1250     0
# Blue vs RankCero     paired     5        10vs5        6.921    7.215    0.1875     0
# Blue vs Nucleo       paired     5        10vs5        6.921    6.793    0.6250     0
# IPC vs Ninguno       paired     10       10vs10       7.083    7.017    0.7695     0
# IPC vs RankSimple    paired     5        10vs5        7.065    5.810    0.0625     0
# IPC vs RankCero      paired     5        10vs5        7.065    7.215    0.6250     0
# IPC vs Nucleo        paired     5        10vs5        7.065    6.793    0.8125     0
# Ninguno vs RankSimple paired     5        10vs5        6.865    5.810    0.1875     0
# Ninguno vs RankCero  paired     5        10vs5        6.865    7.215    0.1875     0
# Ninguno vs Nucleo    paired     5        10vs5        6.865    6.793    1.0000     0
# RankSimple vs RankCero paired     5        5vs5         5.810    7.215    0.0625     0
# RankSimple vs Nucleo paired     5        5vs5         5.810    6.793    0.0625     0
# RankCero vs Nucleo   paired     5        5vs5         7.215    6.793    0.1875     0
#
# === OVERALL SUMMARY ===
# Total comparisons performed: 15
# Significant differences found: 0
# All tests performed as paired tests using truncated vectors
#
# === METHOD RANKING BY MEAN PERFORMANCE ===
# 1 . RankCero : 7.215
# 2 . IPC : 7.083
# 3 . Ninguno : 7.017
# 4 . Nucleo : 6.793
# 5 . Blue : 6.769
# 6 . RankSimple : 5.81
#
# Note: Results with code 0 = no significant difference
#       Results with code 1 = first method significantly better
#       Results with code 2 = second method significantly better

# %%
# Comprehensive Wilcoxon Test Comparison for All Methods
# Data Mining 2025 - Model Comparison Analysis

# USO TODOS LOS VALORES, SI n!=m hago UNPAIRED

# Create list of all methods (excluding empty STD)
methods <- list(
  "Blue" = vBlue,
  "IPC" = vIPC,
  "Ninguno" = vNinguno,
  "RankSimple" = vRankSimple,
  "RankCero" = vRankCero,
  "Nucleo" = vNucleo
)

# Function to perform Wilcoxon test between two vectors
perform_wilcoxon_test <- function(vec1, vec2, name1, name2) {
  # Check if vectors have same length for paired test
  if (length(vec1) != length(vec2)) {
    # Use unpaired test if lengths differ
    wt <- wilcox.test(vec1, vec2, paired = FALSE)
    test_type <- "unpaired"
  } else {
    # Use paired test if lengths are equal
    wt <- wilcox.test(vec1, vec2, paired = TRUE)
    test_type <- "paired"
  }
  
  pvalue <- wt$p.value
  mean1 <- mean(vec1)
  mean2 <- mean(vec2)
  
  # Determine result
  result <- 0
  interpretation <- "No significant difference"
  
  if (pvalue < 0.05) {
    if (mean1 > mean2) {
      result <- 1
      interpretation <- paste(name1, "significantly better than", name2)
    } else {
      result <- 2
      interpretation <- paste(name2, "significantly better than", name1)
    }
  }
  
  return(list(
    comparison = paste(name1, "vs", name2),
    test_type = test_type,
    n1 = length(vec1),
    n2 = length(vec2),
    mean1 = round(mean1, 3),
    mean2 = round(mean2, 3),
    pvalue = round(pvalue, 4),
    result = result,
    interpretation = interpretation
  ))
}

# Perform all pairwise comparisons
results <- list()
method_names <- names(methods)
comparison_count <- 0

cat("=== WILCOXON TEST RESULTS FOR ALL METHOD PAIRS ===\n\n")

for (i in 1:(length(methods) - 1)) {
  for (j in (i + 1):length(methods)) {
    comparison_count <- comparison_count + 1
    
    name1 <- method_names[i]
    name2 <- method_names[j]
    vec1 <- methods[[i]]
    vec2 <- methods[[j]]
    
    # Perform test
    test_result <- perform_wilcoxon_test(vec1, vec2, name1, name2)
    results[[comparison_count]] <- test_result
    
    # Print individual result
    cat("Comparison", comparison_count, ":", test_result$comparison, "\n")
    cat("  Test type:", test_result$test_type, "\n")
    cat("  Sample sizes: n1 =", test_result$n1, ", n2 =", test_result$n2, "\n")
    cat("  Means:", name1, "=", test_result$mean1, ",", name2, "=", test_result$mean2, "\n")
    cat("  P-value:", test_result$pvalue, "\n")
    cat("  Result:", test_result$interpretation, "\n")
    cat("  ---\n")
  }
}

# Create summary table
cat("\n=== SUMMARY TABLE ===\n")
cat(sprintf("%-20s %-10s %-8s %-8s %-8s %-8s %-10s %s\n", 
            "Comparison", "Test", "n1", "n2", "Mean1", "Mean2", "P-value", "Result"))
cat(paste(rep("-", 90), collapse=""), "\n")

for (result in results) {
  cat(sprintf("%-20s %-10s %-8d %-8d %-8.3f %-8.3f %-10.4f %d\n",
              result$comparison,
              result$test_type,
              result$n1,
              result$n2,
              result$mean1,
              result$mean2,
              result$pvalue,
              result$result))
}

# Summary statistics
cat("\n=== OVERALL SUMMARY ===\n")
cat("Total comparisons performed:", comparison_count, "\n")

significant_results <- sum(sapply(results, function(x) x$result != 0))
cat("Significant differences found:", significant_results, "\n")

paired_tests <- sum(sapply(results, function(x) x$test_type == "paired"))
unpaired_tests <- sum(sapply(results, function(x) x$test_type == "unpaired"))
cat("Paired tests:", paired_tests, "\n")
cat("Unpaired tests:", unpaired_tests, "\n")

# Method performance ranking by mean
method_means <- sapply(methods, mean)
method_ranking <- sort(method_means, decreasing = TRUE)

cat("\n=== METHOD RANKING BY MEAN PERFORMANCE ===\n")
for (i in 1:length(method_ranking)) {
  cat(i, ".", names(method_ranking)[i], ":", round(method_ranking[i], 3), "\n")
}

cat("\nNote: Results with code 0 = no significant difference")
cat("\n      Results with code 1 = first method significantly better")
cat("\n      Results with code 2 = second method significantly better\n")
# Out:
# === WILCOXON TEST RESULTS FOR ALL METHOD PAIRS ===
#
# Comparison 1 : Blue vs IPC
#   Test type: paired
#   Sample sizes: n1 = 10 , n2 = 10
#   Means: Blue = 6.769 , IPC = 7.083
#   P-value: 0.2324
#   Result: No significant difference
#   ---
# Comparison 2 : Blue vs Ninguno
#   Test type: paired
#   Sample sizes: n1 = 10 , n2 = 10
#   Means: Blue = 6.769 , Ninguno = 7.017
#   P-value: 0.3223
#   Result: No significant difference
#   ---
# Comparison 3 : Blue vs RankSimple
#   Test type: unpaired
#   Sample sizes: n1 = 10 , n2 = 5
#   Means: Blue = 6.769 , RankSimple = 5.81
#   P-value: 0.2065
#   Result: No significant difference
#   ---
# Comparison 4 : Blue vs RankCero
#   Test type: unpaired
#   Sample sizes: n1 = 10 , n2 = 5
#   Means: Blue = 6.769 , RankCero = 7.215
#   P-value: 0.1292
#   Result: No significant difference
#   ---
# Comparison 5 : Blue vs Nucleo
#   Test type: unpaired
#   Sample sizes: n1 = 10 , n2 = 5
#   Means: Blue = 6.769 , Nucleo = 6.793
#   P-value: 1
#   Result: No significant difference
#   ---
# Comparison 6 : IPC vs Ninguno
#   Test type: paired
#   Sample sizes: n1 = 10 , n2 = 10
#   Means: IPC = 7.083 , Ninguno = 7.017
#   P-value: 0.7695
#   Result: No significant difference
#   ---
# Comparison 7 : IPC vs RankSimple
#   Test type: unpaired
#   Sample sizes: n1 = 10 , n2 = 5
#   Means: IPC = 7.083 , RankSimple = 5.81
#   P-value: 0.028
#   Result: IPC significantly better than RankSimple
#   ---
# Comparison 8 : IPC vs RankCero
#   Test type: unpaired
#   Sample sizes: n1 = 10 , n2 = 5
#   Means: IPC = 7.083 , RankCero = 7.215
#   P-value: 0.5941
#   Result: No significant difference
#   ---
# Comparison 9 : IPC vs Nucleo
#   Test type: unpaired
#   Sample sizes: n1 = 10 , n2 = 5
#   Means: IPC = 7.083 , Nucleo = 6.793
#   P-value: 0.5941
#   Result: No significant difference
#   ---
# Comparison 10 : Ninguno vs RankSimple
#   Test type: unpaired
#   Sample sizes: n1 = 10 , n2 = 5
#   Means: Ninguno = 7.017 , RankSimple = 5.81
#   P-value: 0.04
#   Result: Ninguno significantly better than RankSimple
#   ---
# Comparison 11 : Ninguno vs RankCero
#   Test type: unpaired
#   Sample sizes: n1 = 10 , n2 = 5
#   Means: Ninguno = 7.017 , RankCero = 7.215
#   P-value: 0.3097
#   Result: No significant difference
#   ---
# Comparison 12 : Ninguno vs Nucleo
#   Test type: unpaired
#   Sample sizes: n1 = 10 , n2 = 5
#   Means: Ninguno = 7.017 , Nucleo = 6.793
#   P-value: 0.5135
#   Result: No significant difference
#   ---
# Comparison 13 : RankSimple vs RankCero
#   Test type: paired
#   Sample sizes: n1 = 5 , n2 = 5
#   Means: RankSimple = 5.81 , RankCero = 7.215
#   P-value: 0.0625
#   Result: No significant difference
#   ---
# Comparison 14 : RankSimple vs Nucleo
#   Test type: paired
#   Sample sizes: n1 = 5 , n2 = 5
#   Means: RankSimple = 5.81 , Nucleo = 6.793
#   P-value: 0.0625
#   Result: No significant difference
#   ---
# Comparison 15 : RankCero vs Nucleo
#   Test type: paired
#   Sample sizes: n1 = 5 , n2 = 5
#   Means: RankCero = 7.215 , Nucleo = 6.793
#   P-value: 0.1875
#   Result: No significant difference
#   ---
#
# === SUMMARY TABLE ===
# Comparison           Test       n1       n2       Mean1    Mean2    P-value    Result
# ------------------------------------------------------------------------------------------
# Blue vs IPC          paired     10       10       6.769    7.083    0.2324     0
# Blue vs Ninguno      paired     10       10       6.769    7.017    0.3223     0
# Blue vs RankSimple   unpaired   10       5        6.769    5.810    0.2065     0
# Blue vs RankCero     unpaired   10       5        6.769    7.215    0.1292     0
# Blue vs Nucleo       unpaired   10       5        6.769    6.793    1.0000     0
# IPC vs Ninguno       paired     10       10       7.083    7.017    0.7695     0
# IPC vs RankSimple    unpaired   10       5        7.083    5.810    0.0280     1
# IPC vs RankCero      unpaired   10       5        7.083    7.215    0.5941     0
# IPC vs Nucleo        unpaired   10       5        7.083    6.793    0.5941     0
# Ninguno vs RankSimple unpaired   10       5        7.017    5.810    0.0400     1
# Ninguno vs RankCero  unpaired   10       5        7.017    7.215    0.3097     0
# Ninguno vs Nucleo    unpaired   10       5        7.017    6.793    0.5135     0
# RankSimple vs RankCero paired     5        5        5.810    7.215    0.0625     0
# RankSimple vs Nucleo paired     5        5        5.810    6.793    0.0625     0
# RankCero vs Nucleo   paired     5        5        7.215    6.793    0.1875     0
#
# === OVERALL SUMMARY ===
# Total comparisons performed: 15
# Significant differences found: 2
# Paired tests: 6
# Unpaired tests: 9
#
# === METHOD RANKING BY MEAN PERFORMANCE ===
# 1 . RankCero : 7.215
# 2 . IPC : 7.083
# 3 . Ninguno : 7.017
# 4 . Nucleo : 6.793
# 5 . Blue : 6.769
# 6 . RankSimple : 5.81
#
# Note: Results with code 0 = no significant difference
#       Results with code 1 = first method significantly better
#       Results with code 2 = second method significantly better
